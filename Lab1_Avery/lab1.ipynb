# %%
from exceptions import TextFormatException, MissingValueException, MeasurementUnitException

# %%
def compute_BMI(height: float, weight: float) -> float:
    return weight/(height**2)

# %%
def parse_row(row: str) -> list:
    values = row.strip().split(",") 
    exam_id = int(values[0])
    date = values[1]
    name = values[2]
    weight_str = values[3]

    if not weight_str:
        raise MissingValueException()
    try:
        weight = float(weight_str)
    except ValueError:
        raise TextFormatException()

    height = float(values[4])

    if height >= 3:
        raise MeasurementUnitException()

    return [exam_id, date, name, weight, height]

# %%
def main():
    input_file = open("data.csv", "r")
    output_file = open('output.csv', 'w')
    try:
        output_file.write('Exam ID, BMI\n')
        input_file.readline()
        for row in input_file:
            try:
                exam_id, date, name, weight, height =  parse_row(row)
                bmi = compute_BMI(height, weight)
                output_file.write(f'{exam_id}, {bmi}\n')
            except MissingValueException:
                print(f'{exam_id} weight is empty')
            except TextFormatException:
                print(f'{exam_id} weight is not a number')
            except MeasurementUnitException:
                print(f'{exam_id} height is in incorrect units')
            except:
                print('unknown error has occured')
    finally:
        input_file.close()
        output_file.close()

# %%
main()
# Out:
# 189 weight is empty
# 294 height is in incorrect units
# 376 weight is empty
# 521 height is in incorrect units
# 776 weight is not a number
# 831 weight is empty
# 842 height is in incorrect units

# %%
test_correct = '1,10/2/2002,Wyn Grey,90,1.76'
test_missing = '1,10/2/2002,Wyn Grey,,1.76'
test_format = '1,10/2/2002,Wyn Grey,abc,1.76'
test_units = '1,10/2/2002,Wyn Grey,90,6.3'

# %%
parse_row(test_correct)
# Out:
# [1, '10/2/2002', 'Wyn Grey', 90.0, 1.76]

# %%
parse_row(test_missing)
# Out:
# ---------------------------------------------------------------------------
# MissingValueException                     Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 parse_row(test_missing)
#
# Cell In[34], line 9, in parse_row(row)
#       5     name = values[2]
#       6     weight_str = values[3]
#       7
#       8     if not weight_str:
# ----> 9         raise MissingValueException()
#      10     try:
#      11         weight = float(weight_str)
#      12     except ValueError:
#
# MissingValueException:

# %%
parse_row(test_format)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 13, in parse_row(row)
#      11         weight = float(weight_str)
#      12     except ValueError:
# ---> 13         raise TextFormatException()
#      14
#
# ValueError: could not convert string to float: 'abc'
#
# During handling of the above exception, another exception occurred:
#
# TextFormatException                       Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 parse_row(test_format)
#
# Cell In[34], line 13, in parse_row(row)
#       9         raise MissingValueException()
#      10     try:
#      11         weight = float(weight_str)
#      12     except ValueError:
# ---> 13         raise TextFormatException()
#      14
#      15     height = float(values[4])
#      16
#
# TextFormatException:

# %%
parse_row(test_units)
# Out:
# ---------------------------------------------------------------------------
# MeasurementUnitException                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 parse_row(test_units)
#
# Cell In[34], line 18, in parse_row(row)
#      14
#      15     height = float(values[4])
#      16
#      17     if height >= 3:
# ---> 18         raise MeasurementUnitException()
#      19
#      20     return [exam_id, date, name, weight, height]
#
# MeasurementUnitException:

# %%
def create_stop_words(file_path: str) -> set:
    stop_words = set()
    with open(file_path, 'r') as input_file:
        for line in input_file:
            word = line.strip().lower()
            if word:
                stop_words.add(word)
    return stop_words

# %%
def parse_text(file_path: str, stop_words: set) -> list:
    punctuation = "!\"#$%&'()*+,-./:;<=>?@[\\]^_`{|}~"
    words = []
    with open(file_path, 'r') as input_file:
        for line in input_file:
            line = line.strip()
            if not line:
                continue
            for word in line.split():
                cleaned = word.strip(punctuation).lower()
                if cleaned and cleaned not in stop_words:
                    words.append(cleaned)
    return words

# %%
def term_frequency(word: int, total_words: int) -> float:
    return word / total_words

# %%
def word_count(words: list) -> dict:
    word_dict = {}
    for word in words:
        if word in word_dict:
            word_dict[word] += 1
        else:
            word_dict[word] = 1
    return word_dict

# %%
def compute_frequencies(word_counts: dict, word_total: int) -> dict:
    new_dict = {}
    for key, value in word_counts.items():
        freq = term_frequency(value, word_total)
        new_dict[key] = round(freq, 5)
    return new_dict

# %%
def common_words(dict1: dict, dict2: dict) -> set:
    common = dict1.keys() & dict2.keys()
    return common

# %%
def unique_words(dict1: dict, common: set) -> set:
    unique = {key: value for key, value in dict1.items() if key not in common}
    return unique

# %%
def create_word_freq(file_path: str, stop_words: set) -> dict:
    txt_list = parse_text(file_path, stop_words)
    txt_words_dict = word_count(txt_list)
    # do we calc word freq with before or after we filter out the stop words (effect total word count)
    txt_freq = compute_frequencies(txt_words_dict, len(txt_list))
    return txt_freq

# %%
def main():
    try:
        stop_words = create_stop_words('stopwords.txt')
        file_A = create_word_freq('textA.txt', stop_words)
        file_B = create_word_freq('textB.txt', stop_words)

        # print(file_A, file_B)
        common = common_words(file_A, file_B)
        unique_A = unique_words(file_A, common)
        unique_B = unique_words(file_B, common)
        # print(unique_A)
        # print(unique_B)
        return unique_A, unique_B
        
    except FileNotFoundError as e:
        print(f"Missing file: {e.filename}")
        
    except Exception as e:
        print(f"Error: {e}")
        # raise e

# %%
main()
# Out:
# ({'first': 0.01887,
#   'step': 0.01887,
#   'knowledge': 0.01887,
#   'mystery': 0.01887,
#   'life': 0.03774,
#   'recognition': 0.01887,
#   'monstrous': 0.01887,
#   'nature': 0.01887,
#   'earthly': 0.01887,
#   'human': 0.01887,
#   'realm': 0.01887,
#   'well': 0.01887,
#   'glory': 0.01887,
#   'realization': 0.01887,
#   'cannot': 0.01887,
#   'changed': 0.01887,
#   'think': 0.01887,
#   'could': 0.01887,
#   'created': 0.01887,
#   'without': 0.07547,
#   'pain': 0.01887,
#   'sorrow': 0.01887,
#   'time': 0.01887,
#   'death': 0.01887,
#   'unfit': 0.01887,
#   'illumination': 0.01887,
#   'proceed': 0.01887,
#   'following': 0.01887,
#   'path': 0.01887,
#   'birds': 0.01887,
#   'shit': 0.01887,
#   "don't": 0.01887,
#   'bother': 0.01887,
#   'brush': 0.01887,
#   'getting': 0.01887,
#   'comedic': 0.01887,
#   'view': 0.01887,
#   'situation': 0.01887,
#   'gives': 0.01887,
#   'spiritual': 0.01887,
#   'distance': 0.01887,
#   'humor': 0.01887,
#   'saves': 0.01887,
#   'joseph': 0.01887,
#   'campbell': 0.01887},
#  {'true': 0.01163,
#   'splendor': 0.01163,
#   'science': 0.01163,
#   'much': 0.02326,
#   'names': 0.01163,
#   'classifies': 0.01163,
#   'records': 0.01163,
#   'predicts': 0.01163,
#   'observes': 0.01163,
#   'desires': 0.01163,
#   'facts': 0.02326,
#   'whatever': 0.01163,
#   'may': 0.02326,
#   'turn': 0.01163,
#   'however': 0.01163,
#   'confuse': 0.01163,
#   'conventions': 0.01163,
#   'reality': 0.02326,
#   'arbitrary': 0.01163,
#   'divisions': 0.01163,
#   'openness': 0.01163,
#   'sincerity': 0.01163,
#   'mind': 0.02326,
#   'bears': 0.01163,
#   'resemblance': 0.01163,
#   'religion': 0.01163,
#   'understood': 0.01163,
#   'deeper': 0.01163,
#   'greater': 0.01163,
#   'scientist': 0.01163,
#   'impressed': 0.01163,
#   'ignorance': 0.02326,
#   'realizes': 0.01163,
#   'laws': 0.01163,
#   'labels': 0.01163,
#   'descriptions': 0.01163,
#   'definitions': 0.01163,
#   'products': 0.01163,
#   'thought': 0.01163,
#   'help': 0.01163,
#   'use': 0.01163,
#   'world': 0.01163,
#   'purposes': 0.01163,
#   'devising': 0.01163,
#   'rather': 0.01163,
#   'understand': 0.01163,
#   'explain': 0.01163,
#   'analyzes': 0.01163,
#   'infinitesimals': 0.01163,
#   'things': 0.01163,
#   'finds': 0.01163,
#   'classify': 0.01163,
#   'perceives': 0.01163,
#   'relativity': 0.01163,
#   'classification': 0.01163,
#   'seems': 0.01163,
#   'increase': 0.01163,
#   'geometric': 0.01163,
#   'progression': 0.01163,
#   'knows': 0.01163,
#   'steadily': 0.01163,
#   'approaches': 0.01163,
#   'point': 0.01163,
#   'unknown': 0.01163,
#   'mere': 0.01163,
#   'blank': 0.01163,
#   'space': 0.01163,
#   'web': 0.01163,
#   'words': 0.01163,
#   'window': 0.02326,
#   'whose': 0.01163,
#   'name': 0.01163,
#   'alan': 0.01163,
#   'watts': 0.01163})

# %% [markdown]
# # Empty stopwordsfile

# %%
def main():
    try:
        stop_words = create_stop_words('stopwordsEmpty.txt')
        file_A = create_word_freq('textA.txt', stop_words)
        file_B = create_word_freq('textB.txt', stop_words)

        # print(file_A, file_B)
        common = common_words(file_A, file_B)
        unique_A = unique_words(file_A, common)
        unique_B = unique_words(file_B, common)
        # print(unique_A)
        # print(unique_B)
        return unique_A, unique_B
        
    except FileNotFoundError as e:
        print(f"Missing file: {e.filename}")
        
    except Exception as e:
        print(f"Error: {e}")

main()
# Out:
# ({'first': 0.0087,
#   'step': 0.0087,
#   'knowledge': 0.0087,
#   'mystery': 0.0087,
#   'life': 0.01739,
#   'recognition': 0.0087,
#   'monstrous': 0.0087,
#   'nature': 0.0087,
#   'earthly': 0.0087,
#   'human': 0.0087,
#   'realm': 0.0087,
#   'as': 0.02609,
#   'well': 0.0087,
#   'glory': 0.0087,
#   'realization': 0.0087,
#   'just': 0.0087,
#   'how': 0.01739,
#   'cannot': 0.0087,
#   'will': 0.01739,
#   'changed': 0.0087,
#   'those': 0.0087,
#   'who': 0.0087,
#   'think': 0.0087,
#   'could': 0.0087,
#   'have': 0.0087,
#   'been': 0.0087,
#   'had': 0.0087,
#   'created': 0.0087,
#   'without': 0.03478,
#   'pain': 0.0087,
#   'sorrow': 0.0087,
#   'time': 0.0087,
#   'death': 0.0087,
#   'unfit': 0.0087,
#   'illumination': 0.0087,
#   'you': 0.03478,
#   'proceed': 0.0087,
#   'through': 0.0087,
#   'following': 0.0087,
#   'your': 0.01739,
#   'path': 0.0087,
#   'birds': 0.0087,
#   'shit': 0.0087,
#   'on': 0.0087,
#   "don't": 0.0087,
#   'bother': 0.0087,
#   'brush': 0.0087,
#   'off': 0.0087,
#   'getting': 0.0087,
#   'comedic': 0.0087,
#   'view': 0.0087,
#   'situation': 0.0087,
#   'gives': 0.0087,
#   'spiritual': 0.0087,
#   'distance': 0.0087,
#   'having': 0.0087,
#   'humor': 0.0087,
#   'saves': 0.0087,
#   'joseph': 0.0087,
#   'campbell': 0.0087},
#  {'true': 0.00505,
#   'splendor': 0.00505,
#   'science': 0.00505,
#   'so': 0.00505,
#   'much': 0.0101,
#   'names': 0.00505,
#   'classifies': 0.00505,
#   'records': 0.00505,
#   'predicts': 0.00505,
#   'but': 0.01515,
#   'observes': 0.00505,
#   'desires': 0.00505,
#   'facts': 0.0101,
#   'whatever': 0.00505,
#   'may': 0.0101,
#   'turn': 0.00505,
#   'out': 0.00505,
#   'however': 0.00505,
#   'confuse': 0.00505,
#   'with': 0.01515,
#   'conventions': 0.00505,
#   'reality': 0.0101,
#   'arbitrary': 0.00505,
#   'divisions': 0.00505,
#   'in': 0.02525,
#   'openness': 0.00505,
#   'sincerity': 0.00505,
#   'mind': 0.0101,
#   'bears': 0.00505,
#   'some': 0.00505,
#   'resemblance': 0.00505,
#   'religion': 0.00505,
#   'understood': 0.00505,
#   'other': 0.00505,
#   'deeper': 0.00505,
#   'greater': 0.00505,
#   'scientist': 0.00505,
#   'more': 0.02525,
#   'he': 0.0404,
#   'impressed': 0.00505,
#   'his': 0.0202,
#   'ignorance': 0.0101,
#   'realizes': 0.00505,
#   'laws': 0.00505,
#   'labels': 0.00505,
#   'descriptions': 0.00505,
#   'definitions': 0.00505,
#   'products': 0.00505,
#   'thought': 0.00505,
#   'help': 0.00505,
#   'him': 0.00505,
#   'use': 0.00505,
#   'world': 0.00505,
#   'purposes': 0.00505,
#   'devising': 0.00505,
#   'rather': 0.00505,
#   'than': 0.00505,
#   'understand': 0.00505,
#   'explain': 0.00505,
#   'analyzes': 0.00505,
#   'into': 0.00505,
#   'infinitesimals': 0.00505,
#   'things': 0.00505,
#   'finds': 0.00505,
#   'classify': 0.00505,
#   'perceives': 0.00505,
#   'relativity': 0.00505,
#   'all': 0.00505,
#   'classification': 0.00505,
#   'what': 0.01515,
#   'does': 0.00505,
#   'seems': 0.00505,
#   'increase': 0.00505,
#   'geometric': 0.00505,
#   'progression': 0.00505,
#   'knows': 0.00505,
#   'steadily': 0.00505,
#   'approaches': 0.00505,
#   'point': 0.00505,
#   'where': 0.00505,
#   'unknown': 0.00505,
#   'mere': 0.00505,
#   'blank': 0.00505,
#   'space': 0.00505,
#   'web': 0.00505,
#   'words': 0.00505,
#   'window': 0.0101,
#   'whose': 0.00505,
#   'name': 0.00505,
#   'alan': 0.00505,
#   'watts': 0.00505})

# %% [markdown]
# # Empty text file

# %%
def main():
    try:
        stop_words = create_stop_words('stopwords.txt')
        file_A = create_word_freq('textEmpty.txt', stop_words)
        file_B = create_word_freq('textB.txt', stop_words)

        # print(file_A, file_B)
        common = common_words(file_A, file_B)
        unique_A = unique_words(file_A, common)
        unique_B = unique_words(file_B, common)
        # print(unique_A)
        # print(unique_B)
        return unique_A, unique_B
        
    except FileNotFoundError as e:
        print(f"Missing file: {e.filename}")
        
    except Exception as e:
        print(f"Error: {e}")

main()
# Out:
# ({},
#  {'true': 0.01163,
#   'splendor': 0.01163,
#   'science': 0.01163,
#   'much': 0.02326,
#   'names': 0.01163,
#   'classifies': 0.01163,
#   'records': 0.01163,
#   'predicts': 0.01163,
#   'observes': 0.01163,
#   'desires': 0.01163,
#   'know': 0.02326,
#   'facts': 0.02326,
#   'whatever': 0.01163,
#   'may': 0.02326,
#   'turn': 0.01163,
#   'however': 0.01163,
#   'confuse': 0.01163,
#   'conventions': 0.01163,
#   'reality': 0.02326,
#   'arbitrary': 0.01163,
#   'divisions': 0.01163,
#   'openness': 0.01163,
#   'sincerity': 0.01163,
#   'mind': 0.02326,
#   'bears': 0.01163,
#   'resemblance': 0.01163,
#   'religion': 0.01163,
#   'understood': 0.01163,
#   'deeper': 0.01163,
#   'sense': 0.01163,
#   'greater': 0.01163,
#   'scientist': 0.01163,
#   'impressed': 0.01163,
#   'ignorance': 0.02326,
#   'realizes': 0.01163,
#   'laws': 0.01163,
#   'labels': 0.01163,
#   'descriptions': 0.01163,
#   'definitions': 0.01163,
#   'products': 0.01163,
#   'thought': 0.01163,
#   'help': 0.01163,
#   'use': 0.01163,
#   'world': 0.01163,
#   'purposes': 0.01163,
#   'devising': 0.01163,
#   'rather': 0.01163,
#   'understand': 0.01163,
#   'explain': 0.01163,
#   'analyzes': 0.01163,
#   'universe': 0.01163,
#   'infinitesimals': 0.01163,
#   'things': 0.01163,
#   'finds': 0.01163,
#   'classify': 0.01163,
#   'perceives': 0.01163,
#   'relativity': 0.01163,
#   'classification': 0.01163,
#   'seems': 0.01163,
#   'increase': 0.01163,
#   'geometric': 0.01163,
#   'progression': 0.01163,
#   'knows': 0.01163,
#   'steadily': 0.01163,
#   'approaches': 0.01163,
#   'point': 0.01163,
#   'unknown': 0.01163,
#   'mere': 0.01163,
#   'blank': 0.01163,
#   'space': 0.01163,
#   'web': 0.01163,
#   'words': 0.01163,
#   'window': 0.02326,
#   'whose': 0.01163,
#   'name': 0.01163,
#   'wonder': 0.01163,
#   'alan': 0.01163,
#   'watts': 0.01163})

# %% [markdown]
# # Missing file path

# %%
def main():
    try:
        stop_words = create_stop_words('stopwords.txt')
        file_A = create_word_freq('textMissing.txt', stop_words)
        file_B = create_word_freq('textB.txt', stop_words)

        # print(file_A, file_B)
        common = common_words(file_A, file_B)
        unique_A = unique_words(file_A, common)
        unique_B = unique_words(file_B, common)
        # print(unique_A)
        # print(unique_B)
        return unique_A, unique_B
        
    except FileNotFoundError as e:
        print(f"Missing file: {e.filename}")
        
    except Exception as e:
        print(f"Error: {e}")

main()
# Out:
# Missing file: textMissing.txt

# %%
from main import load_stopwords, load_words, term_frequency, frequency
# Out:
# Loaded 6 stopwords.
# {'and', 'is', 'it', 'the', 'i', 'to'}
# ------------------------------
# Loaded 4 words from textA file.
# ['cat', 'small', 'dog', 'big']
# Loaded 4 words from textB file.
# ['dog', 'fast', 'cat', 'slow']
# ------------------------------
# Term frequencies for textA:
# {'cat': 0.25, 'small': 0.25, 'dog': 0.25, 'big': 0.25}
# Term frequencies for textB:
# {'dog': 0.25, 'fast': 0.25, 'cat': 0.25, 'slow': 0.25}
# ------------------------------
# ------------------------------
# Common words between textA and textB: {'cat', 'dog'}
# Unique words in textA: {'small': 0.25, 'big': 0.25}
# Unique words in textB: {'fast': 0.25, 'slow': 0.25}

# %% [markdown]
# # Test 1

# %%
stopwords = load_stopwords('./test/stopwords4t1.txt')
stopwords
# Out:
# {'and', 'i', 'is', 'it', 'the', 'to'}

# %% [markdown]
# ## Remaining Words in doc1

# %%
wordA = load_words('./test/textA4t1.txt', stopwords)
wordA
# Out:
# ['cat', 'small', 'dog', 'big']

# %% [markdown]
# ## Remaining Words in doc2

# %%
wordB = load_words('./test/textB4t1.txt', stopwords)
wordB
# Out:
# ['dog', 'fast', 'cat', 'slow']

# %% [markdown]
# ## Term frequency for doc 1

# %%
freqA = term_frequency(wordA)
freqA
# Out:
# {'cat': 0.25, 'small': 0.25, 'dog': 0.25, 'big': 0.25}

# %% [markdown]
# ## Term frequency for doc 2

# %%
freqB = term_frequency(wordB)
freqB
# Out:
# {'dog': 0.25, 'fast': 0.25, 'cat': 0.25, 'slow': 0.25}

# %% [markdown]
# ## Common Words

# %%
common = freqA.keys() & freqB.keys()
common
# Out:
# {'cat', 'dog'}

# %% [markdown]
# ## Unique Words in Doc 1

# %%
unique_a = {key:value for key, value in freqA.items() if key not in common}
unique_a
newWords = list(unique_a.keys())
freqANew = term_frequency(newWords)
freqANew
# Out:
# {'small': 0.5, 'big': 0.5}

# %% [markdown]
# ## Unique Words in Doc 2

# %%
unique_b = {key:value for key, value in freqB.items() if key not in common}
unique_b
# Out:
# {'fast': 0.25, 'slow': 0.25}

# %% [markdown]
# # Test 2

# %% [markdown]
# ## Remaining Words in doc1

# %%
wordA = load_words('./test/textA4t2.txt', stopwords)
wordA
# Out:
# ['like', 'like', 'apples', 'apples']

# %% [markdown]
# ## Remaining Words in doc2

# %%
wordB = load_words('./test/textB4t2.txt', stopwords)
wordB
# Out:
# ['you', 'like', 'apples', 'oranges']

# %% [markdown]
# ## Term frequency for doc 1

# %%
freqA = term_frequency(wordA)
freqA
# Out:
# {'like': 0.5, 'apples': 0.5}

# %% [markdown]
# ## Term frequency for doc 2

# %%
freqB = term_frequency(wordB)
freqB
# Out:
# {'you': 0.25, 'like': 0.25, 'apples': 0.25, 'oranges': 0.25}

# %% [markdown]
# ## Common Words

# %%
common = freqA.keys() & freqB.keys()
common
# Out:
# {'apples', 'like'}

# %% [markdown]
# ## Unique Words in Doc 1

# %%
unique_a = {key:value for key, value in freqA.items() if key not in common}
unique_a
# Out:
# {}

# %% [markdown]
# ## Unique Words in Doc 2

# %%
unique_b = {key:value for key, value in freqB.items() if key not in common}
unique_b
# Out:
# {'you': 0.25, 'oranges': 0.25}

# %% [markdown]
# # Test 3

# %% [markdown]
# ## Remaining Words in doc1

# %%
wordA = load_words('./test/textA4t3.txt', stopwords)
wordA
# Out:
# ['life',
#  'a',
#  'journey',
#  'not',
#  'a',
#  'destination',
#  'but',
#  'a',
#  'process',
#  'of',
#  'becoming']

# %% [markdown]
# ## Remaining Words in doc2

# %%
wordB = load_words('./test/textB4t3.txt', stopwords)
wordB
# Out:
# ['life',
#  'not',
#  'a',
#  'problem',
#  'be',
#  'solved',
#  'but',
#  'a',
#  'reality',
#  'be',
#  'experienced']

# %% [markdown]
# ## Term frequency for doc 1

# %%
freqA = term_frequency(wordA)
freqA
# Out:
# {'life': 0.09091,
#  'a': 0.27273,
#  'journey': 0.09091,
#  'not': 0.09091,
#  'destination': 0.09091,
#  'but': 0.09091,
#  'process': 0.09091,
#  'of': 0.09091,
#  'becoming': 0.09091}

# %% [markdown]
# ## Term frequency for doc 2

# %%
freqB = term_frequency(wordB)
freqB
# Out:
# {'life': 0.09091,
#  'not': 0.09091,
#  'a': 0.18182,
#  'problem': 0.09091,
#  'be': 0.18182,
#  'solved': 0.09091,
#  'but': 0.09091,
#  'reality': 0.09091,
#  'experienced': 0.09091}

# %% [markdown]
# ## Common Words

# %%
common = freqA.keys() & freqB.keys()
common
# Out:
# {'a', 'but', 'life', 'not'}

# %% [markdown]
# ## Unique Words in Doc 1

# %%
unique_a = {key:value for key, value in freqA.items() if key not in common}
unique_a
# Out:
# {'journey': 0.09091,
#  'destination': 0.09091,
#  'process': 0.09091,
#  'of': 0.09091,
#  'becoming': 0.09091}

# %% [markdown]
# ## Unique Words in Doc 2

# %%
unique_b = {key:value for key, value in freqB.items() if key not in common}
unique_b
# Out:
# {'problem': 0.09091,
#  'be': 0.18182,
#  'solved': 0.09091,
#  'reality': 0.09091,
#  'experienced': 0.09091}

# %% [markdown]
# # Lab Data

# %%
stopwords = load_stopwords('./data/stopwords.txt')
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'don',
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'has',
#  'have',
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'me',
#  'more',
#  'most',
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'now',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  's',
#  'same',
#  'she',
#  'should',
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  'the',
#  'their',
# ...

# %% [markdown]
# ## Remaining Words in doc1

# %%
wordA = load_words('./data/textA.txt', stopwords)
wordA
# Out:
# ['first',
#  'step',
#  'knowledge',
#  'wonder',
#  'mystery',
#  'life',
#  'recognition',
#  'monstrous',
#  'nature',
#  'earthly',
#  'human',
#  'realm',
#  'well',
#  'glory',
#  'realization',
#  'cannot',
#  'changed',
#  'think',
#  'know',
#  'universe',
#  'could',
#  'created',
#  'without',
#  'pain',
#  'without',
#  'sorrow',
#  'without',
#  'time',
#  'without',
#  'death',
#  'unfit',
#  'illumination',
#  'proceed',
#  'life',
#  'following',
#  'path',
#  'birds',
#  'shit',
#  "don't",
#  'bother',
#  'brush',
#  'getting',
#  'comedic',
#  'view',
#  'situation',
#  'gives',
#  'spiritual',
#  'distance',
#  'sense',
#  'humor',
#  'saves',
#  'joseph',
#  'campbell']

# %% [markdown]
# ## Remaining Words in doc2

# %%
wordB = load_words('./data/textB.txt', stopwords)
wordB
# Out:
# ['true',
#  'splendor',
#  'science',
#  'much',
#  'names',
#  'classifies',
#  'records',
#  'predicts',
#  'observes',
#  'desires',
#  'know',
#  'facts',
#  'whatever',
#  'may',
#  'turn',
#  'however',
#  'much',
#  'may',
#  'confuse',
#  'facts',
#  'conventions',
#  'reality',
#  'arbitrary',
#  'divisions',
#  'openness',
#  'sincerity',
#  'mind',
#  'bears',
#  'resemblance',
#  'religion',
#  'understood',
#  'deeper',
#  'sense',
#  'greater',
#  'scientist',
#  'impressed',
#  'ignorance',
#  'reality',
#  'realizes',
#  'laws',
#  'labels',
#  'descriptions',
#  'definitions',
#  'products',
#  'thought',
#  'help',
#  'use',
#  'world',
#  'purposes',
#  'devising',
#  'rather',
#  'understand',
#  'explain',
#  'analyzes',
#  'universe',
#  'infinitesimals',
#  'things',
#  'finds',
#  'classify',
#  'perceives',
#  'relativity',
#  'classification',
#  'know',
#  'seems',
#  'increase',
#  'geometric',
#  'progression',
#  'knows',
#  'steadily',
#  'approaches',
# ...

# %% [markdown]
# ## Term frequency for doc 1

# %%
freqA = term_frequency(wordA)
freqA
# Out:
# {'first': 0.01887,
#  'step': 0.01887,
#  'knowledge': 0.01887,
#  'wonder': 0.01887,
#  'mystery': 0.01887,
#  'life': 0.03774,
#  'recognition': 0.01887,
#  'monstrous': 0.01887,
#  'nature': 0.01887,
#  'earthly': 0.01887,
#  'human': 0.01887,
#  'realm': 0.01887,
#  'well': 0.01887,
#  'glory': 0.01887,
#  'realization': 0.01887,
#  'cannot': 0.01887,
#  'changed': 0.01887,
#  'think': 0.01887,
#  'know': 0.01887,
#  'universe': 0.01887,
#  'could': 0.01887,
#  'created': 0.01887,
#  'without': 0.07547,
#  'pain': 0.01887,
#  'sorrow': 0.01887,
#  'time': 0.01887,
#  'death': 0.01887,
#  'unfit': 0.01887,
#  'illumination': 0.01887,
#  'proceed': 0.01887,
#  'following': 0.01887,
#  'path': 0.01887,
#  'birds': 0.01887,
#  'shit': 0.01887,
#  "don't": 0.01887,
#  'bother': 0.01887,
#  'brush': 0.01887,
#  'getting': 0.01887,
#  'comedic': 0.01887,
#  'view': 0.01887,
#  'situation': 0.01887,
#  'gives': 0.01887,
#  'spiritual': 0.01887,
#  'distance': 0.01887,
# ...

# %% [markdown]
# ## Term frequency for doc 2

# %%
freqB = term_frequency(wordB)
freqB
# Out:
# {'true': 0.01163,
#  'splendor': 0.01163,
#  'science': 0.01163,
#  'much': 0.02326,
#  'names': 0.01163,
#  'classifies': 0.01163,
#  'records': 0.01163,
#  'predicts': 0.01163,
#  'observes': 0.01163,
#  'desires': 0.01163,
#  'know': 0.02326,
#  'facts': 0.02326,
#  'whatever': 0.01163,
#  'may': 0.02326,
#  'turn': 0.01163,
#  'however': 0.01163,
#  'confuse': 0.01163,
#  'conventions': 0.01163,
#  'reality': 0.02326,
#  'arbitrary': 0.01163,
#  'divisions': 0.01163,
#  'openness': 0.01163,
#  'sincerity': 0.01163,
#  'mind': 0.02326,
#  'bears': 0.01163,
#  'resemblance': 0.01163,
#  'religion': 0.01163,
#  'understood': 0.01163,
#  'deeper': 0.01163,
#  'sense': 0.01163,
#  'greater': 0.01163,
#  'scientist': 0.01163,
#  'impressed': 0.01163,
#  'ignorance': 0.02326,
#  'realizes': 0.01163,
#  'laws': 0.01163,
#  'labels': 0.01163,
#  'descriptions': 0.01163,
#  'definitions': 0.01163,
#  'products': 0.01163,
#  'thought': 0.01163,
#  'help': 0.01163,
#  'use': 0.01163,
# ...

# %% [markdown]
# ## Common Words

# %%
common = freqA.keys() & freqB.keys()
common
# Out:
# {'know', 'sense', 'universe', 'wonder'}

# %% [markdown]
# ## Unique Words in Doc 1

# %%
unique_a = {key:value for key, value in freqA.items() if key not in common}
unique_a
# Out:
# {'first': 0.01887,
#  'step': 0.01887,
#  'knowledge': 0.01887,
#  'mystery': 0.01887,
#  'life': 0.03774,
#  'recognition': 0.01887,
#  'monstrous': 0.01887,
#  'nature': 0.01887,
#  'earthly': 0.01887,
#  'human': 0.01887,
#  'realm': 0.01887,
#  'well': 0.01887,
#  'glory': 0.01887,
#  'realization': 0.01887,
#  'cannot': 0.01887,
#  'changed': 0.01887,
#  'think': 0.01887,
#  'could': 0.01887,
#  'created': 0.01887,
#  'without': 0.07547,
#  'pain': 0.01887,
#  'sorrow': 0.01887,
#  'time': 0.01887,
#  'death': 0.01887,
#  'unfit': 0.01887,
#  'illumination': 0.01887,
#  'proceed': 0.01887,
#  'following': 0.01887,
#  'path': 0.01887,
#  'birds': 0.01887,
#  'shit': 0.01887,
#  "don't": 0.01887,
#  'bother': 0.01887,
#  'brush': 0.01887,
#  'getting': 0.01887,
#  'comedic': 0.01887,
#  'view': 0.01887,
#  'situation': 0.01887,
#  'gives': 0.01887,
#  'spiritual': 0.01887,
#  'distance': 0.01887,
#  'humor': 0.01887,
#  'saves': 0.01887,
#  'joseph': 0.01887,
# ...

# %% [markdown]
# ## Unique Words in Doc 2

# %%
unique_b = {key:value for key, value in freqB.items() if key not in common}
unique_b
# Out:
# {'true': 0.01163,
#  'splendor': 0.01163,
#  'science': 0.01163,
#  'much': 0.02326,
#  'names': 0.01163,
#  'classifies': 0.01163,
#  'records': 0.01163,
#  'predicts': 0.01163,
#  'observes': 0.01163,
#  'desires': 0.01163,
#  'facts': 0.02326,
#  'whatever': 0.01163,
#  'may': 0.02326,
#  'turn': 0.01163,
#  'however': 0.01163,
#  'confuse': 0.01163,
#  'conventions': 0.01163,
#  'reality': 0.02326,
#  'arbitrary': 0.01163,
#  'divisions': 0.01163,
#  'openness': 0.01163,
#  'sincerity': 0.01163,
#  'mind': 0.02326,
#  'bears': 0.01163,
#  'resemblance': 0.01163,
#  'religion': 0.01163,
#  'understood': 0.01163,
#  'deeper': 0.01163,
#  'greater': 0.01163,
#  'scientist': 0.01163,
#  'impressed': 0.01163,
#  'ignorance': 0.02326,
#  'realizes': 0.01163,
#  'laws': 0.01163,
#  'labels': 0.01163,
#  'descriptions': 0.01163,
#  'definitions': 0.01163,
#  'products': 0.01163,
#  'thought': 0.01163,
#  'help': 0.01163,
#  'use': 0.01163,
#  'world': 0.01163,
#  'purposes': 0.01163,
# ...

# %% [markdown]
# # Special Test

# %%
wordEmpty = load_words('./test/empty.txt', stopwords)
wordEmpty
# Out:
# []

# %%
freq0 = frequency(1/0)
freq0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 freq0 = frequency(1/0)
#       2 freq0
#
# ZeroDivisionError: division by zero

# %%
wordExist = load_words('./test/empt11.txt', stopwords)
wordExist
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/University/Data2402/Group7-/Lab2/Lab2-Solution/main.py:24, in load_words(filename, stopwords)
#      23 try:
# ---> 24     with open(filename, 'r') as input_file:
#      25             for line in input_file:
#
# FileNotFoundError: [Errno 2] No such file or directory: './test/empt11.txt'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 wordExist = load_words('./test/empt11.txt', stopwords)
#       2 wordExist
#
# File ~/University/Data2402/Group7-/Lab2/Lab2-Solution/main.py:35, in load_words(filename, stopwords)
#      33     return words
#      34 except:
# ---> 35     raise FileNotFoundError(f"Error: The file '{filename}' was not found.")
#
# ...
